# %%
# 경고무시
import warnings
warnings.filterwarnings(action='ignore', category=DeprecationWarning)

# %%
# load library
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 10

# %%
# load data
online_data = pd.read_csv("C:/nh/2019N매출.csv")
online_data.head()
# Out:
#   Unnamed: 0                      비온라인          온라인
# 0        합계액  827700225774-17285020239  17285020239

# %%
# 결측치 파악
online_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1 non-null      object
#  1   비온라인        1 non-null      object
#  2   온라인         1 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 152.0+ bytes

# %%
ratio = [0.979116811, 0.020883189]
labels = ['비온라인','온라인']
explode = (0.0, 0.1)
colors = ['lightgray', 'gold']

fig = plt.figure(figsize=(8,8))
fig.set_facecolor('white')
ax = fig.add_subplot()

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()

# %%
# 2021년 매출액

ratio = [0.948813844, 0.051186156]
labels = ['오프라인','온라인']
explode = (0.0, 0.1)
colors = ['lightgray', 'gold']

fig = plt.figure(figsize=(8,8))
fig.set_facecolor('white')
ax = fig.add_subplot()

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()
