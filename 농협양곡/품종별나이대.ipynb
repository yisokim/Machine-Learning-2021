# %%
# 경고무시
import warnings
warnings.filterwarnings(action='ignore', category=DeprecationWarning)

# %%
# load library
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 10

# %%
# load data
# 2021-01-01_2021-06-30
online_data = pd.read_csv("C:/nh/품종.csv")
online_data.head()
# Out:
#   상품카테고리(세)      상품명   품종    무게  성별     나이     결제금액  결제수  결제상품수량 환불금액  환불건수  \
# 0        백미   NH신동진쌀  신동진  10kg  남성  36~40  274,200    5       8    0     0
# 1        백미   NH신동진쌀  신동진  10kg  여성  36~40   68,800    2       2    0     0
# 2        백미   NH신동진쌀  신동진  10kg  여성  46~50   68,800    2       2    0     0
# 3        백미   NH신동진쌀  신동진  10kg  남성  41~45   68,800    2       2    0     0
# 4        백미   NH신동진쌀  신동진  10kg  남성  61~65   68,800    2       2    0     0
#
#    환불수량   실결제금액  실결제수량
# 0     0  274200      8
# 1     0   68800      2
# 2     0   68800      2
# 3     0   68800      2
# 4     0   68800      2

# %%
# 결측치 확인
online_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 873 entries, 0 to 872
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   상품카테고리(세)  873 non-null    object
#  1   상품명        873 non-null    object
#  2   품종         873 non-null    object
#  3   무게         873 non-null    object
#  4   성별         873 non-null    object
#  5   나이         873 non-null    object
#  6   결제금액       873 non-null    object
#  7   결제수        873 non-null    int64
#  8   결제상품수량     873 non-null    int64
#  9   환불금액       873 non-null    object
#  10  환불건수       873 non-null    int64
#  11  환불수량       873 non-null    int64
#  12  실결제금액      873 non-null    int64
#  13  실결제수량      873 non-null    int64
# dtypes: int64(6), object(8)
# memory usage: 95.6+ KB

# %%
pd.set_option('display.max_rows', None)

# %%
# 품종별 나이대
grouped_name_s_r = online_data.groupby(['품종','나이'])['실결제금액'].sum()
grouped_name_s_r
# Out:
# 품종     나이
# 고시히카리  20~25      445900
#        26~30     1735400
#        31~35     6060200
#        36~40     6765700
#        41~45     6814700
#        46~50     3606500
#        51~55     2830200
#        56~60     2276500
#        61~65      690500
#        66~70       79900
#        71+         83800
# 삼광     20~25      491300
#        26~30     1008400
#        31~35     1233700
#        36~40     2646600
#        41~45     2292700
#        46~50     1944100
#        51~55     1376600
#        56~60      744300
#        61~65      261000
#        66~70      202500
# 새청무    20~25      120400
#        26~30      839300
#        31~35      361200
#        36~40      120400
#        41~45      177600
#        46~50      601500
#        51~55      120400
#        56~60      361200
#        61~65      301000
#        66~70       60200
#        71+         60200
# 신동진    20~25     1773600
#        26~30     2973200
#        31~35     5273700
#        36~40     9240800
# ...

# %%
품종별나이_결제금액 = pd.DataFrame(grouped_name_s_r, columns=['실결제금액'])
품종별나이_결제금액
# Out:
#                 실결제금액
# 품종    나이
# 고시히카리 20~25    445900
#       26~30   1735400
#       31~35   6060200
#       36~40   6765700
#       41~45   6814700
#       46~50   3606500
#       51~55   2830200
#       56~60   2276500
#       61~65    690500
#       66~70     79900
#       71+       83800
# 삼광    20~25    491300
#       26~30   1008400
#       31~35   1233700
#       36~40   2646600
#       41~45   2292700
#       46~50   1944100
#       51~55   1376600
#       56~60    744300
#       61~65    261000
#       66~70    202500
# 새청무   20~25    120400
#       26~30    839300
#       31~35    361200
#       36~40    120400
#       41~45    177600
#       46~50    601500
#       51~55    120400
#       56~60    361200
#       61~65    301000
#       66~70     60200
#       71+       60200
# 신동진   20~25   1773600
#       26~30   2973200
#       31~35   5273700
#       36~40   9240800
#       41~45   7408000
#       46~50   9458400
#       51~55   4539300
#       56~60   2008400
# ...

# %%
품종별나이_결제수량.to_csv('품종나이_결제수량.csv', index=False, sep=' ',encoding='utf8')
