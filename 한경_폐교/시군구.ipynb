# %%
# 경고무시
import warnings
warnings.filterwarnings(action='ignore', category=DeprecationWarning)

# %%
# load library
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 10

# %%
# load data
online_data = pd.read_csv("C:/폐교/경로당.csv")
online_data.head()
# Out:
#    시군구       명칭  이용 회원수                      시설 소재지 Unnamed: 4   관할읍면동
# 0  포항시   매산리경로당    30.0     포항시 북구 흥해읍 매산길 24번길 12         NaN  흥해읍사무소
# 1  포항시  매산부녀경로당    45.0         포항시 북구 흥해읍 매산리 394         NaN  흥해읍사무소
# 2  포항시   북송리경로당    45.0   포항시 북구 흥해읍 신흥로 694번길 9-4         NaN  흥해읍사무소
# 3  포항시  북송부녀경로당    60.0          포항시 북구 흥해읍 신흥로 728        NaN  흥해읍사무소
# 4  포항시   마산리경로당    30.0  포항시 북구 흥해읍 신흥로 898번길 19-4         NaN  흥해읍사무소

# %%
# 결측치 확인
online_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7854 entries, 0 to 7853
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   시군구         7854 non-null   object
#  1   명칭          7854 non-null   object
#  2   이용 회원수      7850 non-null   float64
#  3   시설 소재지      7854 non-null   object
#  4   Unnamed: 4  944 non-null    object
#  5    관할읍면동      7854 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 368.3+ KB

# %%
# 통계량 파악
online_data['시군구'].describe()
# Out:
# count     7854
# unique      23
# top        경주시
# freq       607
# Name: 시군구, dtype: object

# %%
# 시군구 경로당 분포수
online_data.groupby('시군구').count()
# Out:
#       명칭  이용 회원수  시설 소재지  Unnamed: 4   관할읍면동
# 시군구
# 경산시  368     368     368          23     368
# 경주시  607     607     607         606     607
# 고령군  198     198     198           0     198
# 구미시  388     388     388           0     388
# 군위군  208     208     208           0     208
# 김천시  510     510     510           0     510
# 문경시  367     367     367           0     367
# 봉화군  248     248     248           0     248
# 상주시  578     578     578           0     578
# 성주군  274     274     274           0     274
# 안동시  516     516     516           0     516
# 영덕군  235     235     235           0     235
# 영양군  161     161     161           0     161
# 영주시  335     335     335           0     335
# 영천시  414     414     414           0     414
# 예천군  343     343     343           0     343
# 울릉군   22      22      22           1      22
# 울진군  246     246     246           0     246
# 의성군  476     475     476           0     476
# 청도군  314     314     314         314     314
# ...

# %%
grouped_name_s_r = online_data.groupby(['시군구'])['이용 회원수'].sum()
grouped_name_s_r
# Out:
# 시군구
# 경산시    15397.0
# 경주시    26506.0
# 고령군     6158.0
# 구미시    16152.0
# 군위군     3085.0
# 김천시    17502.0
# 문경시    15601.0
# 봉화군     9390.0
# 상주시    24855.0
# 성주군    10178.0
# 안동시    23367.0
# 영덕군    10834.0
# 영양군     5404.0
# 영주시    14751.0
# 영천시    17987.0
# 예천군    14330.0
# 울릉군     1105.0
# 울진군     6293.0
# 의성군    20386.0
# 청도군     7655.0
# 청송군     6584.0
# 칠곡군     5181.0
# 포항시    22180.0
# Name: 이용 회원수, dtype: float64

# %%
# load data
online_data = pd.read_csv("C:/폐교/응급.csv")
online_data.head()
# Out:
#          구 분            병 원 명                  주 소  병원분류          전화번호  시군읍
# 0  권역응급 의료센터             안동병원        경북 안동시 앙실로 11  종합병원  054-840-1119  안동시
# 1  권역응급 의료센터  차의과학대학교부속 구미차병원    경북 구미시 신시로 10길 12  종합병원  054-450-9997  구미시
# 2  지역응급 의료센터           포항성모병원    경북 포항시 남구 대잠동길 17  종합병원  054-260-8119  포항시
# 3  지역응급 의료센터         포항세명기독병원  경북 포항시 남구 포스코대로 351  종합병원  054-289-1711  포항시
# 4  지역응급 의료센터    동국대학교의과대학경주병원        경북 경주시 동대로 87  종합병원  054-770-8306  경주시

# %%
# 시군구 경로당 분포수
online_data.groupby('시군읍').count()
# Out:
#      구 분  병 원 명  주 소  병원분류  전화번호
# 시군읍
# 경산시    2      2    2     2     2
# 경주시    1      1    1     1     1
# 고령군    1      1    1     1     1
# 구미시    4      4    4     4     4
# 김천시    2      2    2     2     2
# 문경시    2      2    2     2     2
# 상주시    2      2    2     2     2
# 성주군    1      1    1     1     1
# 안동시    3      3    3     3     3
# 영주시    3      3    3     3     3
# 영천시    1      1    1     1     1
# 예천군    1      1    1     1     1
# 울릉군    1      1    1     1     1
# 울진군    1      1    1     1     1
# 의성군    1      1    1     1     1
# 청도군    1      1    1     1     1
# 청송군    1      1    1     1     1
# 포항시    5      5    5     5     5

# %%
# load data
online_data = pd.read_csv("C:/폐교/경상북도_소방서현황.csv")
online_data.head()
# Out:
#        명 칭               위 치              관할구역1 관할구역2
# 0  포항북부소방서    포항시 북구 중앙로 332          포항시 북구 일원   포항시
# 1  포항남부소방서  포항시 남구 동해안로 5890  포항시 남구 일원/ 울릉군 일원   포항시
# 2  포항남부소방서  포항시 남구 동해안로 5890                NaN   울릉군
# 3    경주소방서      경주시 알천남로 276             경주시 일원   경주시
# 4    김천소방서        김천시 황산로 67             김천시 일원   김천시

# %%
# 시군구 경로당 분포수
online_data.groupby('관할구역2').count()
# Out:
#        명 칭  위 치  관할구역1
# 관할구역2
# 경산시      1    1      1
# 경주시      1    1      1
# 고령군      1    1      1
# 구미시      1    1      1
# 군위군      1    1      0
# 김천시      1    1      1
# 문경시      1    1      1
# 봉화군      1    1      0
# 상주시      1    1      1
# 성주군      1    1      1
# 안동시      1    1      1
# 영덕군      1    1      1
# 영양군      1    1      0
# 영주시      1    1      1
# 영천시      1    1      1
# 예천군      1    1      0
# 울릉군      1    1      0
# 울진군      1    1      1
# 의성군      1    1      1
# 청도군      1    1      1
# 청송군      1    1      0
# 칠곡군      1    1      1
# 포항시      2    2      2
